# %% [markdown]
# # Children's Speech ASR — Whisper-small + BitFit Fine-tuning
#
# This notebook fine-tunes `openai/whisper-small` with **BitFit**, a simple
# parameter-efficient fine-tuning method that updates **only the bias terms**
# of the model while keeping all other weights frozen. Despite its simplicity,
# BitFit can achieve competitive performance by adjusting the model’s decision
# boundaries without modifying the underlying feature representations.
#
#
# Evaluation metric: **Word Error Rate (WER)**.
#
#
# **GenAI statement**: Code assistance provided by ChatGPT (OpenAI). All outputs were reviewed
# and verified for technical accuracy by the student.
#
# ---
# Dataset: https://www.drivendata.org/competitions/308/childrens-word-asr/page/980/

# %%
# Set cache directories (UCL lab machines)
import os
os.environ['HF_HOME']       = '/cs/student/project_msc/2025/dsml/nmxian/huggingface_cache'
os.environ['TORCH_HOME']    = '/cs/student/project_msc/2025/dsml/nmxian/torch_cache'
os.environ['KAGGLEHUB_CACHE'] = '/cs/student/project_msc/2025/dsml/nmxian/kaggle_cache'

# %%
# ── 0. Install required libraries ────────────────────────────────────────────
#!pip install -q transformers datasets soundfile librosa jiwer scikit-learn peft accelerate evaluate numpy pandas matplotlib

# %%
# ── 1. Imports ────────────────────────────────────────────────────────────────
import os, json, random
from pathlib import Path
from dataclasses import dataclass
from typing import Dict, List
from collections import Counter

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import soundfile as sf
import librosa
import jiwer

from torch.utils.data import Dataset
from transformers import (
    WhisperProcessor,
    WhisperForConditionalGeneration,
    Seq2SeqTrainingArguments,
    Seq2SeqTrainer,
)
from peft import LoraConfig, get_peft_model, TaskType, PeftModel

print(f"torch       : {torch.__version__}")
print(f"CUDA        : {torch.cuda.is_available()}")
import peft; print(f"peft        : {peft.__version__}")
import transformers; print(f"transformers: {transformers.__version__}")
# Out:
# torch       : 2.8.0+cu128
# CUDA        : True
# peft        : 0.17.1
# transformers: 4.57.6

# %%
# ── 2. Configuration ──────────────────────────────────────────────────────────

DATA_ROOT        = Path("/cs/student/project_msc/2025/dsml/nmxian/comp0197-cw2")
MODEL_NAME       = "openai/whisper-small"
SAMPLE_RATE      = 16_000
MAX_DURATION_SEC = 30.0

# Set to None to use full dataset
NUM_TRAIN_SAMPLES = None
NUM_EVAL_SAMPLES  = None

# BitFit setting
BITFIT_TRAIN_BIAS_ONLY = True

# Training hyper-parameters
BATCH_SIZE    = 16
LEARNING_RATE = 1e-4
NUM_EPOCHS    = 5
NUM_BEAMS     = 5    # beam search width for inference and eval
OUTPUT_DIR    = str(DATA_ROOT / "whisper_bitfit")
SEED          = 42

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
# Out:
# Device: cuda

# %%
# ── 3. Load speaker-independent splits ───────────────────────────────────────
def load_jsonl(path):
    with open(path) as f:
        return [json.loads(line) for line in f]

train_raw = load_jsonl(DATA_ROOT / "train_word_transcripts_spkind.jsonl")
val_raw   = load_jsonl(DATA_ROOT / "val_word_transcripts_spkind.jsonl")
test_raw  = load_jsonl(DATA_ROOT / "test_word_transcripts_spkind.jsonl")

df_train = pd.DataFrame(train_raw)
df_val   = pd.DataFrame(val_raw)
df_test  = pd.DataFrame(test_raw)

for name, df in [("train", df_train), ("val", df_val), ("test", df_test)]:
    print(f"\n{name} — {len(df):,} utterances")
    print(f"  Children   : {df['child_id'].nunique():,}")
    print(f"  Age dist   :\n{df['age_bucket'].value_counts().to_string()}")
    print(f"  Duration   : mean={df['audio_duration_sec'].mean():.1f}s  "
          f"max={df['audio_duration_sec'].max():.1f}s")

# Verify no child overlap
train_ids = set(df_train["child_id"])
val_ids   = set(df_val["child_id"])
test_ids  = set(df_test["child_id"])
print(f"\nChild overlap — train∩val: {len(train_ids & val_ids)}, "
      f"train∩test: {len(train_ids & test_ids)}, val∩test: {len(val_ids & test_ids)}")
# Out:
# train — 67,041 utterances
#   Children   : 1,495
#   Age dist   :
# age_bucket
# 8-11    51945
# 5-7      8051
# 3-4      7045
#   Duration   : mean=7.1s  max=1348.7s
#
# val — 14,308 utterances
#   Children   : 299
#   Age dist   :
# age_bucket
# 8-11    11091
# 5-7      1721
# 3-4      1496
#   Duration   : mean=6.6s  max=78.0s
#
# test — 14,223 utterances
#   Children   : 381
#   Age dist   :
# age_bucket
# 8-11    10934
# 5-7      1718
# 3-4      1571
#   Duration   : mean=6.6s  max=109.5s
#
# Child overlap — train∩val: 0, train∩test: 0, val∩test: 0

# %%
# ── 4. Filter by duration ────────────────────────────────────────────────────
def filter_duration(df, max_sec=MAX_DURATION_SEC):
    return df[df["audio_duration_sec"] <= max_sec].reset_index(drop=True)

df_train = filter_duration(df_train)
df_val   = filter_duration(df_val)
df_test  = filter_duration(df_test)

train_data = df_train.to_dict("records")
eval_data  = df_val.to_dict("records")
test_data  = df_test.to_dict("records")

if NUM_TRAIN_SAMPLES:
    train_data = train_data[:NUM_TRAIN_SAMPLES]
if NUM_EVAL_SAMPLES:
    eval_data = eval_data[:NUM_EVAL_SAMPLES]

print(f"Train : {len(train_data):,}")
print(f"Eval  : {len(eval_data):,}")
print(f"Test  : {len(test_data):,}")
# Out:
# Train : 65,337
# Eval  : 14,079
# Test  : 13,964

# %%
# ── 5. Audio utility ──────────────────────────────────────────────────────────
def load_audio(audio_path_rel: str) -> np.ndarray:
    path = DATA_ROOT / audio_path_rel
    audio, sr = sf.read(str(path))
    if audio.ndim > 1:
        audio = audio.mean(axis=1)
    if sr != SAMPLE_RATE:
        audio = librosa.resample(audio.astype(np.float32),
                                 orig_sr=sr, target_sr=SAMPLE_RATE)
    return audio.astype(np.float32)

# %%
# ── 6. Processor ──────────────────────────────────────────────────────────────
processor = WhisperProcessor.from_pretrained(
    MODEL_NAME, language="English", task="transcribe"
)
print("Vocab size:", processor.tokenizer.vocab_size)
# Out:
# Vocab size: 50258

# %%
# ── 7. Dataset & collator (identical to whisper_small notebook) ───────────────
class WhisperSpeechDataset(Dataset):
    def __init__(self, records, processor):
        self.records   = records
        self.processor = processor

    def __len__(self):
        return len(self.records)

    def __getitem__(self, idx):
        item  = self.records[idx]
        audio = load_audio(item['audio_path'])
        feat  = self.processor.feature_extractor(
            audio, sampling_rate=SAMPLE_RATE, return_tensors="pt"
        )
        input_features = feat.input_features.squeeze(0)
        labels = self.processor.tokenizer(
            item['orthographic_text'].lower(), return_tensors="pt"
        ).input_ids.squeeze(0)
        return {"input_features": input_features, "labels": labels}


@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
    processor: WhisperProcessor

    def __call__(self, features: List[Dict]) -> Dict[str, torch.Tensor]:
        input_features = torch.stack([f["input_features"] for f in features])
        label_list = [f["labels"] for f in features]
        max_len    = max(l.shape[0] for l in label_list)
        labels     = torch.full((len(label_list), max_len), -100, dtype=torch.long)
        for i, lbl in enumerate(label_list):
            labels[i, :lbl.shape[0]] = lbl
        return {"input_features": input_features, "labels": labels}

# %%
# ── 8. Load base model & apply BitFit ──────────────────────────────────────────
base_model = WhisperForConditionalGeneration.from_pretrained(MODEL_NAME)

# Generation config
forced_decoder_ids = processor.get_decoder_prompt_ids(
    language="english", task="transcribe"
)
base_model.config.forced_decoder_ids = forced_decoder_ids
base_model.config.suppress_tokens = []
base_model.config.use_cache = False
base_model.generation_config.language = "english"
base_model.generation_config.task = "transcribe"
base_model.generation_config.forced_decoder_ids = forced_decoder_ids

# BitFit: freeze everything first
for param in base_model.parameters():
    param.requires_grad = False

# Unfreeze only bias terms
for name, param in base_model.named_parameters():
    if "bias" in name:
        param.requires_grad = True

model = base_model.to(device)

# Print trainable parameters
total = sum(p.numel() for p in model.parameters())
trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)

print("\nTrainable parameter names:")
for name, param in model.named_parameters():
    if param.requires_grad:
        print(f"  {name} | shape={tuple(param.shape)} | numel={param.numel():,}")

print(f"\nTotal params     : {total:,}")
print(f"Trainable params : {trainable:,}  ({100 * trainable / total:.4f}%)")
# Out:
# Trainable parameter names:
#   model.encoder.conv1.bias | shape=(768,) | numel=768
#   model.encoder.conv2.bias | shape=(768,) | numel=768
#   model.encoder.layers.0.self_attn.v_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.0.self_attn.q_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.0.self_attn.out_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.0.self_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.encoder.layers.0.fc1.bias | shape=(3072,) | numel=3,072
#   model.encoder.layers.0.fc2.bias | shape=(768,) | numel=768
#   model.encoder.layers.0.final_layer_norm.bias | shape=(768,) | numel=768
#   model.encoder.layers.1.self_attn.v_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.1.self_attn.q_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.1.self_attn.out_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.1.self_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.encoder.layers.1.fc1.bias | shape=(3072,) | numel=3,072
#   model.encoder.layers.1.fc2.bias | shape=(768,) | numel=768
#   model.encoder.layers.1.final_layer_norm.bias | shape=(768,) | numel=768
#   model.encoder.layers.2.self_attn.v_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.2.self_attn.q_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.2.self_attn.out_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.2.self_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.encoder.layers.2.fc1.bias | shape=(3072,) | numel=3,072
#   model.encoder.layers.2.fc2.bias | shape=(768,) | numel=768
#   model.encoder.layers.2.final_layer_norm.bias | shape=(768,) | numel=768
#   model.encoder.layers.3.self_attn.v_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.3.self_attn.q_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.3.self_attn.out_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.3.self_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.encoder.layers.3.fc1.bias | shape=(3072,) | numel=3,072
#   model.encoder.layers.3.fc2.bias | shape=(768,) | numel=768
#   model.encoder.layers.3.final_layer_norm.bias | shape=(768,) | numel=768
#   model.encoder.layers.4.self_attn.v_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.4.self_attn.q_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.4.self_attn.out_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.4.self_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.encoder.layers.4.fc1.bias | shape=(3072,) | numel=3,072
#   model.encoder.layers.4.fc2.bias | shape=(768,) | numel=768
#   model.encoder.layers.4.final_layer_norm.bias | shape=(768,) | numel=768
#   model.encoder.layers.5.self_attn.v_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.5.self_attn.q_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.5.self_attn.out_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.5.self_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.encoder.layers.5.fc1.bias | shape=(3072,) | numel=3,072
#   model.encoder.layers.5.fc2.bias | shape=(768,) | numel=768
#   model.encoder.layers.5.final_layer_norm.bias | shape=(768,) | numel=768
#   model.encoder.layers.6.self_attn.v_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.6.self_attn.q_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.6.self_attn.out_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.6.self_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.encoder.layers.6.fc1.bias | shape=(3072,) | numel=3,072
#   model.encoder.layers.6.fc2.bias | shape=(768,) | numel=768
#   model.encoder.layers.6.final_layer_norm.bias | shape=(768,) | numel=768
#   model.encoder.layers.7.self_attn.v_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.7.self_attn.q_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.7.self_attn.out_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.7.self_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.encoder.layers.7.fc1.bias | shape=(3072,) | numel=3,072
#   model.encoder.layers.7.fc2.bias | shape=(768,) | numel=768
#   model.encoder.layers.7.final_layer_norm.bias | shape=(768,) | numel=768
#   model.encoder.layers.8.self_attn.v_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.8.self_attn.q_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.8.self_attn.out_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.8.self_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.encoder.layers.8.fc1.bias | shape=(3072,) | numel=3,072
#   model.encoder.layers.8.fc2.bias | shape=(768,) | numel=768
#   model.encoder.layers.8.final_layer_norm.bias | shape=(768,) | numel=768
#   model.encoder.layers.9.self_attn.v_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.9.self_attn.q_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.9.self_attn.out_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.9.self_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.encoder.layers.9.fc1.bias | shape=(3072,) | numel=3,072
#   model.encoder.layers.9.fc2.bias | shape=(768,) | numel=768
#   model.encoder.layers.9.final_layer_norm.bias | shape=(768,) | numel=768
#   model.encoder.layers.10.self_attn.v_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.10.self_attn.q_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.10.self_attn.out_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.10.self_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.encoder.layers.10.fc1.bias | shape=(3072,) | numel=3,072
#   model.encoder.layers.10.fc2.bias | shape=(768,) | numel=768
#   model.encoder.layers.10.final_layer_norm.bias | shape=(768,) | numel=768
#   model.encoder.layers.11.self_attn.v_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.11.self_attn.q_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.11.self_attn.out_proj.bias | shape=(768,) | numel=768
#   model.encoder.layers.11.self_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.encoder.layers.11.fc1.bias | shape=(3072,) | numel=3,072
#   model.encoder.layers.11.fc2.bias | shape=(768,) | numel=768
#   model.encoder.layers.11.final_layer_norm.bias | shape=(768,) | numel=768
#   model.encoder.layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.0.self_attn.v_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.0.self_attn.q_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.0.self_attn.out_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.0.self_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.0.encoder_attn.v_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.0.encoder_attn.q_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.0.encoder_attn.out_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.0.encoder_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.0.fc1.bias | shape=(3072,) | numel=3,072
#   model.decoder.layers.0.fc2.bias | shape=(768,) | numel=768
#   model.decoder.layers.0.final_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.1.self_attn.v_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.1.self_attn.q_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.1.self_attn.out_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.1.self_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.1.encoder_attn.v_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.1.encoder_attn.q_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.1.encoder_attn.out_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.1.encoder_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.1.fc1.bias | shape=(3072,) | numel=3,072
#   model.decoder.layers.1.fc2.bias | shape=(768,) | numel=768
#   model.decoder.layers.1.final_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.2.self_attn.v_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.2.self_attn.q_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.2.self_attn.out_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.2.self_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.2.encoder_attn.v_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.2.encoder_attn.q_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.2.encoder_attn.out_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.2.encoder_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.2.fc1.bias | shape=(3072,) | numel=3,072
#   model.decoder.layers.2.fc2.bias | shape=(768,) | numel=768
#   model.decoder.layers.2.final_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.3.self_attn.v_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.3.self_attn.q_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.3.self_attn.out_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.3.self_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.3.encoder_attn.v_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.3.encoder_attn.q_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.3.encoder_attn.out_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.3.encoder_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.3.fc1.bias | shape=(3072,) | numel=3,072
#   model.decoder.layers.3.fc2.bias | shape=(768,) | numel=768
#   model.decoder.layers.3.final_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.4.self_attn.v_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.4.self_attn.q_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.4.self_attn.out_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.4.self_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.4.encoder_attn.v_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.4.encoder_attn.q_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.4.encoder_attn.out_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.4.encoder_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.4.fc1.bias | shape=(3072,) | numel=3,072
#   model.decoder.layers.4.fc2.bias | shape=(768,) | numel=768
#   model.decoder.layers.4.final_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.5.self_attn.v_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.5.self_attn.q_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.5.self_attn.out_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.5.self_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.5.encoder_attn.v_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.5.encoder_attn.q_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.5.encoder_attn.out_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.5.encoder_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.5.fc1.bias | shape=(3072,) | numel=3,072
#   model.decoder.layers.5.fc2.bias | shape=(768,) | numel=768
#   model.decoder.layers.5.final_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.6.self_attn.v_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.6.self_attn.q_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.6.self_attn.out_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.6.self_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.6.encoder_attn.v_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.6.encoder_attn.q_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.6.encoder_attn.out_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.6.encoder_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.6.fc1.bias | shape=(3072,) | numel=3,072
#   model.decoder.layers.6.fc2.bias | shape=(768,) | numel=768
#   model.decoder.layers.6.final_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.7.self_attn.v_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.7.self_attn.q_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.7.self_attn.out_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.7.self_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.7.encoder_attn.v_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.7.encoder_attn.q_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.7.encoder_attn.out_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.7.encoder_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.7.fc1.bias | shape=(3072,) | numel=3,072
#   model.decoder.layers.7.fc2.bias | shape=(768,) | numel=768
#   model.decoder.layers.7.final_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.8.self_attn.v_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.8.self_attn.q_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.8.self_attn.out_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.8.self_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.8.encoder_attn.v_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.8.encoder_attn.q_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.8.encoder_attn.out_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.8.encoder_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.8.fc1.bias | shape=(3072,) | numel=3,072
#   model.decoder.layers.8.fc2.bias | shape=(768,) | numel=768
#   model.decoder.layers.8.final_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.9.self_attn.v_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.9.self_attn.q_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.9.self_attn.out_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.9.self_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.9.encoder_attn.v_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.9.encoder_attn.q_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.9.encoder_attn.out_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.9.encoder_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.9.fc1.bias | shape=(3072,) | numel=3,072
#   model.decoder.layers.9.fc2.bias | shape=(768,) | numel=768
#   model.decoder.layers.9.final_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.10.self_attn.v_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.10.self_attn.q_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.10.self_attn.out_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.10.self_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.10.encoder_attn.v_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.10.encoder_attn.q_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.10.encoder_attn.out_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.10.encoder_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.10.fc1.bias | shape=(3072,) | numel=3,072
#   model.decoder.layers.10.fc2.bias | shape=(768,) | numel=768
#   model.decoder.layers.10.final_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.11.self_attn.v_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.11.self_attn.q_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.11.self_attn.out_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.11.self_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.11.encoder_attn.v_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.11.encoder_attn.q_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.11.encoder_attn.out_proj.bias | shape=(768,) | numel=768
#   model.decoder.layers.11.encoder_attn_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layers.11.fc1.bias | shape=(3072,) | numel=3,072
#   model.decoder.layers.11.fc2.bias | shape=(768,) | numel=768
#   model.decoder.layers.11.final_layer_norm.bias | shape=(768,) | numel=768
#   model.decoder.layer_norm.bias | shape=(768,) | numel=768
#
# Total params     : 241,734,912
# Trainable params : 224,256  (0.0928%)

# %%
# ── 9. WER metric ─────────────────────────────────────────────────────────────
_transform = jiwer.Compose([
    jiwer.ToLowerCase(),
    jiwer.RemovePunctuation(),
    jiwer.Strip(),
    jiwer.RemoveMultipleSpaces(),
    jiwer.ReduceToListOfListOfWords(),
])

def wer_score(refs, hyps):
    return jiwer.process_words(
        refs, hyps,
        reference_transform=_transform,
        hypothesis_transform=_transform,
    ).wer

def compute_metrics(pred):
    pred_ids  = pred.predictions
    label_ids = pred.label_ids.copy()
    label_ids[label_ids == -100] = processor.tokenizer.pad_token_id
    pred_strs  = processor.tokenizer.batch_decode(pred_ids,  skip_special_tokens=True)
    label_strs = processor.tokenizer.batch_decode(label_ids, skip_special_tokens=True)
    return {"wer": wer_score(label_strs, pred_strs)}

# %%
# ── 10. Zero-shot WER (before any fine-tuning) ────────────────────────────────
# Evaluate the base whisper-small (BitFit) on the held-out test set to establish a baseline.
# Uses all of test_data (not a capped subset) for an unbiased estimate.
model.eval()

def transcribe(audio, model, processor, max_new_tokens=225, num_beams=NUM_BEAMS):
    feat = processor.feature_extractor(
        audio, sampling_rate=SAMPLE_RATE, return_tensors="pt"
    )
    input_features = feat.input_features.to(device)
    with torch.no_grad():
        ids = model.generate(input_features=input_features, max_new_tokens=max_new_tokens,
                             num_beams=num_beams)
    return processor.tokenizer.decode(ids[0], skip_special_tokens=True)

zs_preds, zs_refs = [], []
for item in test_data:
    audio = load_audio(item['audio_path'])
    zs_preds.append(transcribe(audio, model, processor))
    zs_refs.append(item['orthographic_text'])

wer_zero_shot = wer_score(zs_refs, zs_preds)
print(f"Zero-shot WER (n={len(test_data)} test samples): {wer_zero_shot:.4f}")
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Zero-shot WER (n=13964 test samples): 0.2780

# %%
# ── 10b. Custom Trainer for Whisper + BitFit ──────────────────────────────────
#
# In BitFit, the model is the original WhisperForConditionalGeneration.
# So we do not need PEFT-specific workarounds such as model.base_model.model.
# We only keep a lightweight override to explicitly pass input_features during
# generation, which can be safer for Whisper in some setups.

class WhisperBitFitTrainer(Seq2SeqTrainer):

    def compute_loss(self, model, inputs, return_outputs=False, **kwargs):
        outputs = model(
            input_features=inputs["input_features"],
            labels=inputs["labels"],
        )
        return (outputs.loss, outputs) if return_outputs else outputs.loss

    def prediction_step(self, model, inputs, prediction_loss_only, ignore_keys=None):
        model.eval()
        inputs = self._prepare_inputs(inputs)

        with torch.no_grad():
            # Always compute teacher-forced loss so Validation Loss is logged.
            loss_outputs = model(
                input_features=inputs["input_features"],
                labels=inputs["labels"],
            )
            loss = loss_outputs.loss.detach()

        if not self.args.predict_with_generate or prediction_loss_only:
            return loss, None, None

        # Generate-based path for WER metric.
        max_len = self.args.generation_max_length or 225
        num_beams = self.args.generation_num_beams or 1
        with torch.no_grad():
            generated = model.generate(
                input_features=inputs["input_features"],
                max_new_tokens=max_len,
                num_beams=num_beams,
            )

        labels = inputs.get("labels")
        if generated.shape[-1] < max_len:
            generated = self._pad_tensors_to_max_len(generated, max_len)
        if labels is not None and labels.shape[-1] < max_len:
            labels = self._pad_tensors_to_max_len(labels, max_len)

        return loss, generated, labels

# %%
# ── 11. Training ──────────────────────────────────────────────────────────────
train_dataset = WhisperSpeechDataset(train_data, processor)
eval_dataset  = WhisperSpeechDataset(eval_data,  processor)
collator      = DataCollatorSpeechSeq2SeqWithPadding(processor=processor)
NUM_EPOCHS    = 10
training_args = Seq2SeqTrainingArguments(
    output_dir                  = OUTPUT_DIR,
    per_device_train_batch_size = BATCH_SIZE,
    per_device_eval_batch_size  = BATCH_SIZE,
    gradient_accumulation_steps = 1,
    warmup_steps                = 100,
    num_train_epochs            = NUM_EPOCHS,
    learning_rate               = LEARNING_RATE,
    fp16                        = torch.cuda.is_available(),
    eval_strategy               = "epoch",
    save_strategy               = "epoch",
    load_best_model_at_end      = True,
    metric_for_best_model       = "wer",
    greater_is_better           = False,
    predict_with_generate       = True,
    generation_max_length       = 225,
    generation_num_beams        = NUM_BEAMS,
    logging_steps               = 50,
    report_to                   = "none",
    dataloader_num_workers      = 4,
    remove_unused_columns       = False,  # required for PEFT
    seed                        = SEED,
)

trainer = WhisperBitFitTrainer(
    model           = model,
    args            = training_args,
    train_dataset   = train_dataset,
    eval_dataset    = eval_dataset,
    data_collator   = collator,
    compute_metrics = compute_metrics,
    tokenizer       = processor.feature_extractor,
)

train_result = trainer.train(resume_from_checkpoint=True)

# Save only the BitFit bias terms
model.save_pretrained(OUTPUT_DIR)
processor.save_pretrained(OUTPUT_DIR)
print(f"BitFit bias terms saved to {OUTPUT_DIR}")
# Out:
# /tmp/ipykernel_209680/3337869634.py:30: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `WhisperBitFitTrainer.__init__`. Use `processing_class` instead.
#   trainer = WhisperBitFitTrainer(
# There were missing keys in the checkpoint model loaded: ['proj_out.weight'].
# There were missing keys in the checkpoint model loaded: ['proj_out.weight'].
#     <div>
#
#       <progress value='40840' max='40840' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [40840/40840 : < :, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# /cs/student/project_msc/2025/dsml/nmxian/my-notebook/myenv/lib64/python3.9/site-packages/transformers/modeling_utils.py:3918: UserWarning: Moving the following attributes in the config to the generation config: {'max_length': 448, 'suppress_tokens': [], 'begin_suppress_tokens': [220, 50257]}. You are seeing this warning because you've set generation parameters in the model config, as opposed to in the generation config.
#   warnings.warn(
# BitFit bias terms saved to /cs/student/project_msc/2025/dsml/nmxian/comp0197-cw2/whisper_bitfit

# %%
# # ── 12. Adapter file size vs full model ───────────────────────────────────────
# import os

# adapter_files = list(Path(OUTPUT_DIR).rglob("adapter_model*"))
# adapter_size  = sum(f.stat().st_size for f in adapter_files) / 1e6  # MB

# # Full whisper-small is ~242 MB on disk
# full_size_mb = 242.0
# print(f"LoRA adapter size : {adapter_size:.1f} MB")
# print(f"Full model size   : ~{full_size_mb:.0f} MB")
# print(f"Size reduction    : {full_size_mb / max(adapter_size, 0.1):.0f}×")

# %%
# ── 13. Evaluation after fine-tuning ─────────────────────────────────────────
eval_results = trainer.evaluate()
wer_bitfit     = eval_results['eval_wer']
print(f"BitFit WER (full eval set): {wer_bitfit:.4f}")

# Training loss curve
log_history = pd.DataFrame(trainer.state.log_history)
if 'loss' in log_history.columns:
    plt.figure(figsize=(8, 4))
    log_history.dropna(subset=['loss'])['loss'].plot()
    plt.title('Training Loss — Whisper-small + BitFit')
    plt.xlabel('step')
    plt.ylabel('loss')
    plt.tight_layout()
    plt.savefig(DATA_ROOT / "whisper_bitfit_train_loss.png", dpi=100)
    plt.show()
# Out:
#     <div>
#
#       <progress value='880' max='880' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [880/880 26:55]
#     </div>
# BitFit WER (full eval set): 0.1465

# %%
wer_bitfit
# Out:
# 0.14645667333772547

# %%
# ── 14. WER by age bucket ─────────────────────────────────────────────────────
model.eval()
age_wer_bitfit = {}
age_wer_zero = {}

for bucket in ['3-4', '5-7', '8-11']:
    bucket_eval = [d for d in eval_data if d['age_bucket'] == bucket]
    if not bucket_eval:
        continue
    preds_bitfit, preds_zero, refs = [], [], []
    for item in bucket_eval:
        audio = load_audio(item['audio_path'])
        preds_bitfit.append(transcribe(audio, model, processor))
        refs.append(item['orthographic_text'])

    age_wer_bitfit[bucket] = wer_score(refs, preds_bitfit)
    print(f"  BitFit  [{bucket}] WER = {age_wer_bitfit[bucket]:.4f}")

# Plot
fig, ax = plt.subplots(figsize=(7, 4))
x  = np.arange(len(age_wer_bitfit))
ax.bar(x, age_wer_bitfit.values(), color='mediumseagreen', label='BitFit fine-tuned')
ax.set_xticks(x)
ax.set_xticklabels(age_wer_bitfit.keys())
ax.set(xlabel='Age bucket', ylabel='WER',
       title='WER by Age Group — Whisper-small + BitFit')
ax.legend()
plt.tight_layout()
plt.savefig(DATA_ROOT / "whisper_bitfit_wer_by_age.png", dpi=100)
plt.show()
# Out:
#   BitFit  [3-4] WER = 0.8267
#   BitFit  [5-7] WER = 0.3094
#   BitFit  [8-11] WER = 0.1191

# %%
# ── 15. Zero-shot vs LoRA comparison ─────────────────────────────────────────
# Re-run zero-shot on same eval_data[:ZERO_SHOT_N] using the base model
# (LoRA adapters are disabled by temporarily merging with scale=0)
# Simplest approach: reload the base model without adapters for zero-shot eval

print("Computing per-age zero-shot WER for comparison...")

base_for_eval = WhisperForConditionalGeneration.from_pretrained(MODEL_NAME).to(device)
base_for_eval.config.forced_decoder_ids   = forced_decoder_ids
base_for_eval.config.suppress_tokens      = []
base_for_eval.generation_config.language  = "english"
base_for_eval.generation_config.task      = "transcribe"
base_for_eval.generation_config.forced_decoder_ids = forced_decoder_ids
base_for_eval.eval()

age_wer_zero = {}
for bucket in ['3-4', '5-7', '8-11']:
    bucket_eval = [d for d in eval_data if d['age_bucket'] == bucket]
    if not bucket_eval:
        continue
    preds, refs = [], []
    for item in bucket_eval:
        audio = load_audio(item['audio_path'])
        preds.append(transcribe(audio, base_for_eval, processor))
        refs.append(item['orthographic_text'])
    age_wer_zero[bucket] = wer_score(refs, preds)
    print(f"  Zero-shot [{bucket}] WER = {age_wer_zero[bucket]:.4f}")

del base_for_eval
torch.cuda.empty_cache()
# Out:
# Computing per-age zero-shot WER for comparison...
#   Zero-shot [3-4] WER = 1.5521
#   Zero-shot [5-7] WER = 1.1410
#   Zero-shot [8-11] WER = 0.1931

# %%
# ── 16. Side-by-side bar chart ────────────────────────────────────────────────
buckets = list(age_wer_zero.keys())
zero_vals = [age_wer_zero[b] for b in buckets]
bitfit_vals = [age_wer_bitfit[b] for b in buckets]

x   = np.arange(len(buckets))
w   = 0.35
fig, ax = plt.subplots(figsize=(8, 5))
bars1 = ax.bar(x - w/2, zero_vals, w, label='Zero-shot',      color='steelblue',     alpha=0.8)
bars2 = ax.bar(x + w/2, bitfit_vals, w, label='BitFit fine-tuned', color='mediumseagreen', alpha=0.8)

for bar in bars1 + bars2:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.005,
            f'{bar.get_height():.3f}', ha='center', va='bottom', fontsize=9)

ax.set_xticks(x)
ax.set_xticklabels(buckets)
ax.set(xlabel='Age bucket', ylabel='WER',
       title='Zero-shot vs BitFit Fine-tuned WER by Age Group\n(Whisper-small)')
ax.legend()
plt.tight_layout()
plt.savefig(DATA_ROOT / "whisper_bitfit_comparison.png", dpi=100)
plt.show()

# Print WER improvement
print("\nWER improvement (zero-shot → BitFit):")
for b in buckets:
    delta = age_wer_zero[b] - age_wer_bitfit[b]
    rel   = delta / age_wer_zero[b] * 100
    print(f"  [{b}]  {age_wer_zero[b]:.4f} → {age_wer_bitfit[b]:.4f}  "
          f"(Δ = {delta:+.4f}, {rel:+.1f}% relative)")
# Out:
# WER improvement (zero-shot → BitFit):
#   [3-4]  1.5521 → 0.8267  (Δ = +0.7254, +46.7% relative)
#   [5-7]  1.1410 → 0.3094  (Δ = +0.8316, +72.9% relative)
#   [8-11]  0.1931 → 0.1191  (Δ = +0.0740, +38.3% relative)

# %%
# ── 17. Beam-search confidence (uncertainty proxy) ────────────────────────────
#
# Whisper returns per-step score tensors when output_scores=True.
# Token-level max-probability = confidence; token-level entropy = aleatoric proxy.

def beam_confidence(audio, model, processor, num_beams=5, max_new_tokens=225):
    feat = processor.feature_extractor(
        audio, sampling_rate=SAMPLE_RATE, return_tensors="pt"
    )
    input_features = feat.input_features.to(device)
    model.eval()
    with torch.no_grad():
        out = model.generate(
            input_features,
            num_beams               = num_beams,
            return_dict_in_generate = True,
            output_scores           = True,
            max_new_tokens          = max_new_tokens,
        )
    # out.scores: tuple of (batch, vocab) tensors, one per generated token
    scores = torch.stack(out.scores, dim=1).squeeze(0)      # (T_gen, vocab)
    probs  = torch.softmax(scores, dim=-1)
    token_conf    = probs.max(dim=-1).values                 # (T_gen,)
    token_entropy = -(probs * torch.log(probs + 1e-10)).sum(dim=-1)  # (T_gen,)
    transcription = processor.tokenizer.decode(
        out.sequences[0], skip_special_tokens=True
    )
    return {
        "transcription" : transcription,
        "mean_conf"     : token_conf.mean().item(),
        "mean_entropy"  : token_entropy.mean().item(),
        "token_conf"    : token_conf.cpu().numpy(),
        "token_entropy" : token_entropy.cpu().numpy(),
    }

# %%
# # ── 18. Uncertainty vs WER ────────────────────────────────────────────────────
# N_UNC = 50
# unc_results = []
# for item in random.sample(eval_data, N_UNC):
#     audio = load_audio(item['audio_path'])
#     b     = beam_confidence(audio, model, processor)
#     wer_i = wer_score([item['orthographic_text']], [b['transcription']])
#     unc_results.append({
#         "reference"  : item['orthographic_text'],
#         "prediction" : b['transcription'],
#         "wer"        : wer_i,
#         "mean_conf"  : b['mean_conf'],
#         "entropy"    : b['mean_entropy'],
#         "age_bucket" : item['age_bucket'],
#     })

# unc_df = pd.DataFrame(unc_results)

# fig, axes = plt.subplots(1, 2, figsize=(12, 4))
# axes[0].scatter(unc_df['mean_conf'],  unc_df['wer'], alpha=0.7, color='mediumseagreen')
# axes[0].set(xlabel='Mean Token Confidence', ylabel='WER',
#             title='Confidence vs WER (LoRA)')
# axes[1].scatter(unc_df['entropy'], unc_df['wer'], alpha=0.7, color='darkorange')
# axes[1].set(xlabel='Mean Token Entropy', ylabel='WER',
#             title='Entropy vs WER (LoRA)')
# plt.tight_layout()
# plt.savefig(DATA_ROOT / "whisper_lora_uncertainty.png", dpi=100)
# plt.show()

# corr = unc_df[['mean_conf', 'entropy', 'wer']].corr()['wer'].drop('wer')
# print("Pearson correlation with WER:\n", corr.round(3))

# %%
# ── 19. Load BitFit model for inference (full model reload) ───────────────────
def load_bitfit_model(model_dir):
    """Reload the full BitFit-tuned Whisper model."""
    model = WhisperForConditionalGeneration.from_pretrained(model_dir)
    model.config.forced_decoder_ids = forced_decoder_ids
    model.config.suppress_tokens = []
    return model

# Quick sanity-check: reload and transcribe one sample
reloaded = load_bitfit_model(OUTPUT_DIR).to(device).eval()
sample = eval_data[0]
audio = load_audio(sample["audio_path"])
hyp = transcribe(audio, reloaded, processor)

print(f"Reference : {sample['orthographic_text']}")
print(f"Hypothesis: {hyp}")

del reloaded
torch.cuda.empty_cache()
# Out:
# `generation_config` default values have been modified to match model-specific defaults: {'suppress_tokens': [], 'begin_suppress_tokens': [220, 50257]}. If this is not desired, please set these values explicitly.
# A custom logits processor of type <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> has been passed to `.generate()`, but it was also created in `.generate()`, given its parameterization. The custom <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> will take precedence. Please check the docstring of <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> to see related `.generate()` flags.
# A custom logits processor of type <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> has been passed to `.generate()`, but it was also created in `.generate()`, given its parameterization. The custom <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> will take precedence. Please check the docstring of <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> to see related `.generate()` flags.
# Reference : it is the liquid i cant hear her um the water is a liquid
# Hypothesis: it is playing the liquid i can't hear who um the water is a liquid

# %%
# ── 20. Parameter efficiency summary table ────────────────────────────────────
full_trainable = sum(p.numel()
                     for p in WhisperForConditionalGeneration
                     .from_pretrained(MODEL_NAME).parameters())

rows = [
    ("Whisper-small (zero-shot)",  full_trainable, 0,         wer_zero_shot),
    ("Whisper-small (full FT)",    full_trainable, full_trainable, float('nan')),
    (f"Whisper-small + BitFit", full_trainable, trainable, wer_bitfit),
]
summary = pd.DataFrame(rows,
    columns=["Model", "Total params", "Trainable params", "WER"])
summary["Trainable %"] = (summary["Trainable params"] / summary["Total params"] * 100).round(2)
print(summary.to_string(index=False))
# Out:
#                     Model  Total params  Trainable params      WER  Trainable %
# Whisper-small (zero-shot)     241734912                 0 0.277961         0.00
#   Whisper-small (full FT)     241734912         241734912      NaN       100.00
#    Whisper-small + BitFit     241734912            224256 0.146457         0.09

# %%
# ── 21. Summary ─────────────────────────────────────────────────────────────

# Guard: compute per-age WER dicts if cells 18/19/20 were not run first
if 'age_wer_bitfit' not in dir() or not age_wer_bitfit:
    print('age_wer_bitfit not found — computing now (BitFit model)...')
    model.eval()
    age_wer_bitfit = {}
    for bucket in ['3-4', '5-7', '8-11']:
        bucket_eval = [d for d in eval_data if d['age_bucket'] == bucket]
        if not bucket_eval:
            continue
        preds_bitfit, refs = [], []
        for item in bucket_eval:
            audio = load_audio(item['audio_path'])
            preds_bitfit.append(transcribe(audio, model, processor))
            refs.append(item['orthographic_text'])
        age_wer_bitfit[bucket] = wer_score(refs, preds_bitfit)
        print(f"  BitFit  [{bucket}] WER = {age_wer_bitfit[bucket]:.4f}")

if 'age_wer_zero' not in dir() or not age_wer_zero:
    print('age_wer_zero not found — computing now (base model)...')
    base_for_eval = WhisperForConditionalGeneration.from_pretrained(MODEL_NAME).to(device)
    base_for_eval.config.forced_decoder_ids   = forced_decoder_ids
    base_for_eval.config.suppress_tokens      = []
    base_for_eval.generation_config.language  = 'english'
    base_for_eval.generation_config.task      = 'transcribe'
    base_for_eval.generation_config.forced_decoder_ids = forced_decoder_ids
    base_for_eval.eval()
    age_wer_zero = {}
    for bucket in ['3-4', '5-7', '8-11']:
        bucket_eval = [d for d in eval_data if d['age_bucket'] == bucket]
        if not bucket_eval:
            continue
        preds, refs = [], []
        for item in bucket_eval:
            audio = load_audio(item['audio_path'])
            preds.append(transcribe(audio, base_for_eval, processor))
            refs.append(item['orthographic_text'])
        age_wer_zero[bucket] = wer_score(refs, preds)
        print(f"  Zero-shot [{bucket}] WER = {age_wer_zero[bucket]:.4f}")
    del base_for_eval
    torch.cuda.empty_cache()

if 'buckets' not in dir() or not buckets:
    buckets = list(age_wer_zero.keys())

print('=' * 60)
print('SUMMARY — Whisper-small + BitFit')
print('=' * 60)
print(f'Base model         : {MODEL_NAME}')
print(f'Trainable params   : {trainable:,}  ({100*trainable/total:.2f}% of total)')
print(f'Train samples      : {len(train_data):,}')
print(f'Eval  samples      : {len(eval_data):,}')
print(f'Epochs             : {NUM_EPOCHS}')
print(f'Zero-shot WER      : {wer_zero_shot:.4f}')
print(f'BitFit WER         : {wer_bitfit:.4f}')
improvement = (wer_zero_shot - wer_bitfit) / wer_zero_shot * 100
print(f'Relative WER Δ     : {improvement:+.1f}%')
print()
print('WER by age bucket:')
for b in buckets:
    print(f'  [{b}]  zero-shot={age_wer_zero[b]:.4f}  BitFit={age_wer_bitfit[b]:.4f}')
# Out:
# ============================================================
# SUMMARY — Whisper-small + BitFit
# ============================================================
# Base model         : openai/whisper-small
# Trainable params   : 224,256  (0.09% of total)
# Train samples      : 65,337
# Eval  samples      : 14,079
# Epochs             : 10
# Zero-shot WER      : 0.2780
# BitFit WER         : 0.1465
# Relative WER Δ     : +47.3%
#
# WER by age bucket:
#   [3-4]  zero-shot=1.5521  BitFit=0.8267
#   [5-7]  zero-shot=1.1410  BitFit=0.3094
#   [8-11]  zero-shot=0.1931  BitFit=0.1191
